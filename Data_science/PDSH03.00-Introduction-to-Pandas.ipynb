# %% [markdown]
# # Data Manipulation with Pandas

# %% [markdown]
# - 앞 장에서 NumPy 패키지에서  ``ndarray`` object를 바탕으로 array를 다루는 방법을 공부하였다.
# - 보다 유연하게 다룰 수 있는 Pandas 패키지가 존재하고 역시 많이 사용되는데 이를 학습한다. 특히 ``Series`` 와``dataFrame`` 이라 불리는 object가 주요 구조체이다.

# %% [markdown]
# ## Installing and Using Pandas
#
# 앞서 NumPy 패키지와 마찬가지로 Pandas 패키지가 설치되어 있어야 한다.
#
# 자세한 사항은 [Pandas documentation](http://pandas.pydata.org/)에서 찾아볼 수 있다.
#
#
# 설치가 되었다면 다음과 같이 버전을 확인할 수 있다.

# %%
import pandas
pandas.__version__
# Out:
# '0.22.0'

# %% [markdown]
# 또한 간단하게 ``pd``로 줄여서 부른다.

# %%
import pandas as pd
