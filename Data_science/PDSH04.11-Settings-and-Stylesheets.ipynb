# %% [markdown]
# # Customizing Matplotlib: Configurations and Stylesheets

# %% [markdown]
# ## Plot Customization by Hand
# 다음 default histogram 결과를 보자.

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
import numpy as np

# %matplotlib inline

# %%
x = np.random.randn(1000)
plt.hist(x);

# %% [markdown]
# ## Stylesheets
#
# 자신만의 stylesheet를 만들거나 이미 포함된 것을 활용함으로써 style을 변경할 수 있다.

# %%
plt.style.available[:5]
# Out:
# ['seaborn', 'seaborn-dark', 'seaborn-poster', 'seaborn-notebook', 'ggplot']

# %% [markdown]
# 다음과 같이 호출하면 그 이후로 계속 변경된 style이 적용된다.
# ``` python
# plt.style.use('stylename')
# ```
#
# 만일 일부만 적용한다면 다음과 같이 사용하면 된다.
# ``` python
# with plt.style.context('stylename'):
#     make_a_plot()
# ```

# %% [markdown]
# 연습을 위해 histogram과 lines을 그리는 함수를 만든다.

# %%
def hist_and_lines():
    np.random.seed(0)
    fig, ax = plt.subplots(1, 2, figsize=(11, 4))
    ax[0].hist(np.random.randn(1000))
    for i in range(3):
        ax[1].plot(np.random.rand(10))
    ax[1].legend(['a', 'b', 'c'], loc='lower left')

# %% [markdown]
# ### FiveThiryEight style

# %%
with plt.style.context('fivethirtyeight'):
    hist_and_lines()

# %% [markdown]
# ### ggplot

# %%
with plt.style.context('ggplot'):
    hist_and_lines()

# %% [markdown]
# ### *Bayesian Methods for Hackers

# %%
with plt.style.context('bmh'):
    hist_and_lines()

# %% [markdown]
# ### Dark background

# %%
with plt.style.context('dark_background'):
    hist_and_lines()

# %% [markdown]
# ### Grayscale

# %%
with plt.style.context('grayscale'):
    hist_and_lines()

# %% [markdown]
# ### Seaborn style

# %%
import seaborn
hist_and_lines()
