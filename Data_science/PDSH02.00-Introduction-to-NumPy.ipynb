# %% [markdown]
# ### **Wecome to Data Science**
#
# ---

# %%
from datascience import *

table = Table().with_column('star',np.arange(6)).with_column('star2',np.arange(6,12,1))

test = table.item(0,0) + table.item(1,0)

test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c78d7f51cd88> in <module>()
#       1 from datascience import *
#       2
# ----> 3 table = Table().with_column('star',np.arange(6)).with_column('star2',np.arange(6,12,1))
#       4
#       5 test = table.item(0,0) + table.item(1,0)
#
# NameError: name 'np' is not defined

# %% [markdown]
# # Introduction to NumPy

# %% [markdown]
# 데이터셋은 매우 다양한 형식의 데이터를 다룬다.
# - collections of documents
# - collections of images
# - collections of sound clips
# - collections of numerical measurements
# - 기타
#
# 그럼에도 불구하고 기본적으로 수배열(arrays of numbers)의 형태로 표현된다.
#
# 따라서 효과적으로 수배열을 저장하고 다루는 것은 Data Science에서 중요하며
# Python에서는 이를 위해 NumPy package와 Pandas package가 유용하게 사용된다.
#
# NumPy (*Numerical Python*)은 Python의 기본 데이터타입인  ``list`` 와 유사하지만 보다 유용하다.
# 자세한 문서는 [http://www.numpy.org/](http://www.numpy.org/)에서 확인할 수 있다.

# %%
import numpy
numpy.__version__
# Out:
# '1.18.5'

# %% [markdown]
# 위와 같이 버전을 확인할 수 있다.
# 일반적으로는 다음과 같이 줄여서 import한다.

# %%
import numpy as np
import random

A=np.arange(10000)
random.shuffle(A)
print(A)
# Out:
# [7157 5884 4868 ... 8657 2874 7758]

# %% [markdown]
# ## 참고사항
#
# IPython과 Notebook은 다음과 같은 형태의 도움말을 제공한다.
#
# 어떤 namespace 내 목록을 보고 싶을 경우, TAB 키를 누른다.
#
# ```ipython
# In [3]: np.<TAB>
# ```
#
# Built-in 문서를 읽고 싶다면 ?를 입력하면 된다.
#
# ```ipython
# In [4]: np?
# ```

# %% [markdown]
# [Understanding Data Types in Python](PDSH02.01-Understanding-Data-Types.ipynb) >
